# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("netflix_titles.csv")
df.head(15)
# Out:
#    show_id     type                                title  \
# 0       s1    Movie                 Dick Johnson Is Dead
# 1       s2  TV Show                        Blood & Water
# 2       s3  TV Show                            Ganglands
# 3       s4  TV Show                Jailbirds New Orleans
# 4       s5  TV Show                         Kota Factory
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 7       s8    Movie                              Sankofa
# 8       s9  TV Show        The Great British Baking Show
# 9      s10    Movie                         The Starling
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                     Bangkok Breaking
# 12     s13    Movie                         Je Suis Karl
# 13     s14    Movie     Confessions of an Invisible Girl
# 14     s15  TV Show      Crime Stories: India Detectives
#
#                          director  \
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
category_value= ['director', 'cast', 'country','date_added', 'rating']
for column in category_value:
    df[column].fillna('missing_string', inplace=True)
numeric_value= ['duration']

for column in numeric_value:
    df[column].fillna(0, inplace=True)

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water   missing_string
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans   missing_string
# 4      s5  TV Show           Kota Factory   missing_string
#
#                                                 cast         country  \
# 0                                     missing_string   United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  missing_string
# 3                                     missing_string  missing_string
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...           India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
duplicates = df.duplicated().sum()
if duplicates > 0:
    print(f'{duplicates} duplicate rows found')
else:
    print('No duplicate rows found')
# Out:
# No duplicate rows found

# %%
shows_per_year = df['release_year'].value_counts().sort_index()
print(shows_per_year)
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.bar(shows_per_year.index, shows_per_year.values, color='darkred', edgecolor='black')
plt.xlabel('Year')
plt.ylabel('Number of Shows')
plt.title('Number of Shows Released Each Year')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
type_count = df['type'].value_counts()
type_count
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
type_count.plot(kind='bar', color='darkred', edgecolor='black')
plt.show()

# %%
genre_list = []
for entry in df['listed_in']:
    genres = entry.split(',')
    for genre in genres:
        genre_list.append(genre.strip())
genre_series = pd.Series(genre_list)
top_genres = genre_series.value_counts().head(10)
print(top_genres)
# Out:
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
top_genres.plot(kind='pie', autopct='%1.1f%%', startangle=150)
plt.title('Top 10 Most Common Genres')
plt.ylabel('')
plt.show()

# %%
country_counts = df['country'].value_counts()
top_10_countries = country_counts.head(10)
print(top_10_countries)
# Out:
# country
# United States     2818
# India              972
# missing_string     831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9, 5))  
top_10_countries.plot(kind='bar', color='darkred') 
plt.title('Top 10 Countries Producing Most Content')
plt.xlabel('Country') 
plt.xticks(rotation=45, ha='right')  
plt.tight_layout() 
plt.show()

# %%
sns.palplot(['#9d0208','#000000','#ffffff','#d00000'])
plt.title("Netflix palette",fontfamily='cursive')
plt.show()

# %%
top_ratings = df['rating'].value_counts().iloc[:15]
top_ratings.plot(kind = 'bar',color='darkred')
plt.show()
